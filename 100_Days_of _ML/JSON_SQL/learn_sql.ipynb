# %% [markdown]
# ## SQL(Structured Query Language)

# %% [markdown]
# It is the standard language used to stor, manage, and retrieve data from databases.
#
# A database is like a digital table system where information is organized in rows and columns.

# %% [markdown]
# Here We will going to learn the the most required topics of SQL
